# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Load processed data
df = pd.read_csv('../data/task2_results.csv')

# Group by sentiment and bank
sentiment_summary = df.groupby(['bank', 'sentiment_label']).size().unstack().fillna(0)
print(sentiment_summary)
# Out:
# sentiment_label              negative  positive
# bank
# Bank of Abyssinia                 225       102
# Commercial Bank of Ethiopia       126       194
# Dashen Bank                        98       241

# %% [markdown]
# ✅ 2. Visualizations (3–5)
# A. Sentiment by Bank

# %%
sns.countplot(data=df, x='bank', hue='sentiment_label')
plt.title('Sentiment Distribution by Bank')
plt.xlabel('Bank')
plt.ylabel('Number of Reviews')
plt.legend(title='Sentiment')
plt.tight_layout()
plt.savefig('../data/sentiment_by_bank.png')

# %% [markdown]
# B. Rating Distribution

# %%
sns.histplot(data=df, x='rating', hue='bank', multiple='dodge', bins=5)
plt.title('Rating Distribution per Bank')
plt.xlabel('Rating')
plt.ylabel('Count')
plt.tight_layout()
plt.savefig('../data/rating_distribution.png')

# %% [markdown]
#  Word Cloud by Theme

# %%
from wordcloud import WordCloud

theme_text = ' '.join(df[df['bank'] == 'Bank of Abyssinia']['review'].dropna().tolist())
wordcloud = WordCloud(width=800, height=400, background_color='white').generate(theme_text)

plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.title('BOA Word Cloud')
plt.savefig('../data/boa_wordcloud.png')

# %% [markdown]
# ✅ 3. Recommendations
# Based on the analysis:
#
# For BOA:
# Fix login reliability: Recurrent issue in negative reviews.
# Optimize performance: Complaints about slow transfers.
#
# For CBE:
# Improve stability: App crashes during transactions.
# Enhance support UX: Users expect quicker help.
#
# For Dashen:
# Introduce new features: Positive sentiment, but users want budgeting tools.
#
# ✅ 4. Ethics & Limitations
# Include in your report:
# “This analysis is based on publicly available Play Store reviews, which may skew negative due to the tendency of users to leave feedback only after bad experiences. Additionally, sentiment models may misclassify sarcasm or code-mixed text.”
